# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-335eb674-bbbc-44e5-af67-ad8b2b5ef3cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-335eb674-bbbc-44e5-af67-ad8b2b5ef3cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/')
# !ls
# Out:
# Mounted at /content/drive
# artist_edges.csv    dataset_descriptions.txt  politician_edges.csv     tvshow_edges.csv
# athletes_edges.csv  government_edges.csv      problem_sheet_3.ipynb
# company_edges.csv   new_sites_edges.csv       public_figure_edges.csv

# %%
df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/tvshow_edges.csv")
print("tvshows")
print (df.head())
G_1 = nx.from_pandas_edgelist(df,source='node_1',target='node_2')

df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/politician_edges.csv")
print("politician\n",df.head())
G_2 = nx.from_pandas_edgelist(df,source="node_1",target="node_2")

df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/artist_edges.csv")
print("artist\n",df.head())
G_8=nx.from_pandas_edgelist(df,"node_1","node_2")

df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/public_figure_edges.csv")
print("public figure\n",df.head())
G_4=nx.from_pandas_edgelist(df,"node_1","node_2")

df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/new_sites_edges.csv")
print("new sites\n",df.head())
G_7=nx.from_pandas_edgelist(df,"node_1","node_2")

df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/government_edges.csv")
print("government\n",df.head())
G_3=nx.from_pandas_edgelist(df,"node_1","node_2")

df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/company_edges.csv")
print("company\n",df.head())
G_6=nx.from_pandas_edgelist(df,"node_1","node_2")

df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/problem sheet 3/athletes_edges.csv")
print("athelets\n",df.head())
G_5=nx.from_pandas_edgelist(df,"node_1","node_2")

graph=[G_1,G_2,G_3,G_4,G_5,G_6,G_7,G_8]
titles=["tvshows","politician",'government','public figure','athelets','company','new sites','artist']
print("\n")
for i in range (5,8):
  print(f"{titles[i]}:")
  print(f"\n for graph. {titles[i]}")
  node_n=graph[i].number_of_nodes()
  print(f"no fo nodes:",node_n)
  print(f"degree of each node{dict(graph[i].degree())}")
  '''if nx.is_connected(graph[i]):
    eccentricity_n = nx.eccentricity(graph[i])
  else:
    # Get all connected components
    components = (graph[i].subgraph(c).copy() for c in nx.connected_components(graph[i]))
    eccentricity_n = {}
    for component in components:
        ecc = nx.eccentricity(component)
  eccentricity_n.update(ecc)
  max_eccentricity=max(eccentricity_n,key=eccentricity_n.get)
  print(f"the node with maximum eccentricity of the graph :{titles[i]} is {max_eccentricity}:{eccentricity_n[max_eccentricity]}")
  degree_centrality_n=nx.degree_centrality(graph[i])
  max_negree_centrality_n=max(degree_centrality_n,key=degree_centrality_n.get)
  print(f"the node with maximum degree centrality:{max_negree_centrality_n,degree_centrality_n[max_negree_centrality_n]} in the graph {titles[i]}")
  closeness_centrality_n=nx.closeness_centrality(graph[i])
  max_closeness_centrality_n=max(closeness_centrality_n,key=closeness_centrality_n.get)
  print(f"the node with maximum closeeness centrality:{max_closeness_centrality_n,closeness_centrality_n[max_closeness_centrality_n]}in the graph {titles[i]}")'''
  betweenness_centrality_n=nx.betweenness_centrality(graph[i])
  max_betweenness_centrality_n=max(betweenness_centrality_n,key=betweenness_centrality_n.get)
  print(f"the node with the maximum betweeness centrality is:{max_betweenness_centrality_n,betweenness_centrality_n[max_betweenness_centrality_n]}in the graph {titles[i]}")
  eigenvector_centrality_n=nx.eigenvector_centrality(graph[i])
  max_eigenvector_centrality_n=max(eigenvector_centrality_n,key=eigenvector_centrality_n.get)
  print(f"the node with the higghest eigen vector centrality is:{max_eigenvector_centrality_n,eigenvector_centrality_n[max_eigenvector_centrality_n]}in the graph {titles[i]}")
  print("\\n")
  #nx.draw(graph[i])
# Out:
# tvshows
#    node_1  node_2
# 0       0    1838
# 1       0    1744
# 2       0      14
# 3       0    2543
# 4       1    1009
# politician
#     node_1  node_2
# 0       0    1972
# 1       0    5111
# 2       0     138
# 3       0    3053
# 4       0    1473
# artist
#     node_1  node_2
# 0       0    1794
# 1       0    3102
# 2       0   16645
# 3       0   23490
# 4       0   42128
# public figure
#     node_1  node_2
# 0       0    1490
# 1       0    2742
# 2       0    7265
# 3       0    8076
# 4       0    8844
# new sites
#     node_1  node_2
# 0       0    9461
# 1       0   13035
# 2       0   12979
# 3       0   24089
# 4       0   10036
# government
#     node_1  node_2
# 0       0    3630
# 1       0    4634
# 2       0    5187
# 3       0    3428
# 4       0     928
# company
#     node_1  node_2
# 0       0    2243
# 1       0   12084
# 2       0    6169
# 3       0    4887
# 4       0    3694
# athelets
#     node_1  node_2
# 0       0    7061
# ...
