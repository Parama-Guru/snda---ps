# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
from google.colab import files
# Use the file upload widget to upload the CSV file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-af6878f7-634e-497a-a96d-e95ec54f9930" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af6878f7-634e-497a-a96d-e95ec54f9930">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/')
# !ls
# Out:
# Mounted at /content/drive
# dolphins.gml  netscience.gml  p1_2_2.csv  p1_2.csv  problem_sheet_1_sna.ipynb  skillgraph.gexf
# karate.gexf   p1_1.csv	      p1_2_3.csv  p1_3.csv  problem_sheet_2_sna.ipynb

# %%
#QUESTION 1:
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/p1_1.csv',index_col=0)
print(df.head())
G = nx.from_pandas_adjacency(df)
nx.draw(G,with_labels=True)
# Out:
#       MIT  HARV  CARN  CASE  LINC  BBN
# MIT     0     0     0     0     1    1
# HARV    0     0     1     0     0    1
# CARN    0     1     0     1     0    0
# CASE    0     0     1     0     1    0
# LINC    1     0     0     1     0    0

# %%
#QUESTION 2.1:
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/p1_2.csv',index_col=0)
print(df.head())
G_1 = nx.from_pandas_adjacency(df)
nx.draw(G_1,with_labels=True)
# Out:
#    A  B  C  D
# A  0  1  1  1
# B  1  0  1  1
# C  1  1  0  1
# D  1  1  1  0

# %%
#QUESTION 2.2:
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/p1_2_2.csv',index_col=0)
print(df.head())
G_2 = nx.from_pandas_adjacency(df)
nx.draw(G_2,with_labels=True)
# Out:
#    P  Q  R  S  T
# P  0  1  1  0  1
# Q  1  0  0  1  1
# R  1  0  0  1  1
# S  0  1  1  0  1
# T  1  1  1  1  0

# %%
#QUESTION 2.3:
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/p1_2_3.csv',index_col=0)
print(df.head())
G_3 = nx.from_pandas_adjacency(df)
nx.draw(G_3,with_labels=True)
# Out:
#    I  J  K  L  M  N  O
# I  0  1  1  0  0  0  1
# J  1  0  0  1  0  0  1
# K  1  0  0  0  1  0  1
# L  0  1  0  0  0  1  1
# M  0  0  1  0  0  1  1

# %%
#QUESTION 3:
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/SOCIAL NETWORK ANALYSIS/p1_3.csv',index_col=0)
print(df.head())
G_4 = nx.from_pandas_adjacency(df)
nx.draw(G_4,with_labels=True)
# Out:
#       SDC  RAND  SRI  UCLA  UCSB  IPTO  BBN  MIT
# SDC     0     1    0     0     0     0    0    0
# RAND    1     0    0     1     0     0    1    0
# SRI     0     0    0     1     1     0    0    1
# UCLA    0     1    1     0     1     0    0    0
# UCSB    0     0    1     1     0     0    0    0
